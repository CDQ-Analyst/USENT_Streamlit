# %%
partner = 'SacValleyMedShare' 
# OID = 'urn:oid:2.16.840.1.113883.3.1108'
# OID = '2.16.840.1.113883.3.1108'
output_path = r"C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml"

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="01"; # Select month, day, and year




partner = 'SacValleyMedShare' 
# OID = 'urn:oid:2.16.840.1.113883.3.1108'
# OID = '2.16.840.1.113883.3.1108'
output_path = r"C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml"


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="02"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="06"; # Select month, day, and year

partner = 'SacValleyMedShare' 
# OID = 'urn:oid:2.16.840.1.113883.3.1108'
# OID = '2.16.840.1.113883.3.1108'
output_path = r"C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml"

# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="07"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="08"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="09"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="11"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\Documents\USENT\USENT_by_partnerName.py:45, in <module>
#      43 path1 = re.sub(pattern, '', path1.strip())
#      44 path2 = re.sub(pattern, '', path2.strip())
# ---> 45 path3 = re.sub(pattern, '', path3.strip())
#      46 path4 = re.sub(pattern, '', path4.strip())
#      47 path5 = re.sub(pattern, '', path5.strip())
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="12"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="13"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="14"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="15"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="16"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="18"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="19"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="20"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="21"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="22"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="23"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="25"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="26"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="27"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="28"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="29"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="07"; day="31"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\Documents\USENT\USENT_by_partnerName.py:43, in <module>
#      40 pattern = ".*" + "\n"
#      42 path0 = re.sub(pattern, '', path0.strip())
# ---> 43 path1 = re.sub(pattern, '', path1.strip())
#      44 path2 = re.sub(pattern, '', path2.strip())
#      45 path3 = re.sub(pattern, '', path3.strip())
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
df1.shape
# Out:
# (84, 17)

# %%
nd.shape
nd['xml']=np.where(nd.CCDA_File_Name.str.contains('xml', case=False, na=False), 'xml',"Other")
nd['xml'].value_counts()
# Out:
# xml    84
# Name: xml, dtype: int64

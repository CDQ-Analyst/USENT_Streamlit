# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="01"; # Select month, day, and year




partner = 'SacValleyMedShare' 
# OID = 'urn:oid:2.16.840.1.113883.3.1108'
# OID = '2.16.840.1.113883.3.1108'
output_path = r"C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml"


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220801 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 36,671
#
# (4)  Total # of Summary of Episode Note files = 24
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.07 %
#
#
# run time: hour:min:sec=  0:01:25.971714

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="02"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~\Documents\USENT\USENT_by_partnerName.py:54, in <module>
#      52 df=[]
#      53 for f in glob.glob(os.path.join(target_path, csvpath)):
# ---> 54     df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
#      55     df.append(df_z)
#      56 df=pd.concat(df,ignore_index=True)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1255, in TextFileReader.read(self, nrows)
#    1253 nrows = validate_integer("nrows", nrows)
#    1254 try:
# -> 1255     index, columns, col_dict = self._engine.read(nrows)
#    1256 except Exception:
#    1257     self.close()
#
# File ~\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="03"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220803 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 262,635
#
# (4)  Total # of Summary of Episode Note files = 17
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:55.827586

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="04"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220804 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 189,700
#
# (4)  Total # of Summary of Episode Note files = 3
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.0 %
#
#
# run time: hour:min:sec=  0:01:52.610052

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="06"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220606 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 17,844
#
# (4)  Total # of Summary of Episode Note files = 0
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.0 %
#
#
# run time: hour:min:sec=  0:00:25.187783

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="07"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220607 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 527,486
#
# (4)  Total # of Summary of Episode Note files = 45
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:03:53.803138

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="08"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220808 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 16,641
#
# (4)  Total # of Summary of Episode Note files = 1
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:00:11.196413

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="09"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220809 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 323,338
#
# (4)  Total # of Summary of Episode Note files = 35
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:03.055083

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="10"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220810 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 390,258
#
# (4)  Total # of Summary of Episode Note files = 43
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:39.590329

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="11"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220811 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 362,355
#
# (4)  Total # of Summary of Episode Note files = 20
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:14.976926

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="13"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220613 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 66,803
#
# (4)  Total # of Summary of Episode Note files = 4
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:01:12.858145

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="14"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220614 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 876,367
#
# (4)  Total # of Summary of Episode Note files = 88
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:04:43.452707

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="15"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220815 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 11,793
#
# (4)  Total # of Summary of Episode Note files = 1
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:00:09.118096

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="16"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220816 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 361,214
#
# (4)  Total # of Summary of Episode Note files = 33
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:29.890167

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="17"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="18"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220818 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 324,767
#
# (4)  Total # of Summary of Episode Note files = 23
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:01:53.598254

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="20"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="21"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220621 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 30,387
#
# (4)  Total # of Summary of Episode Note files = 0
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.0 %
#
#
# run time: hour:min:sec=  0:00:45.525714

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="22"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220822 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 9,382
#
# (4)  Total # of Summary of Episode Note files = 0
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.0 %
#
#
# run time: hour:min:sec=  0:00:07.872032

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="23"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220823 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 414,427
#
# (4)  Total # of Summary of Episode Note files = 52
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:29.455169

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="24"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220824 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 331,463
#
# (4)  Total # of Summary of Episode Note files = 41
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:01:59.193176

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="25"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220825 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 355,938
#
# (4)  Total # of Summary of Episode Note files = 36
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:16.080215

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="27"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220627 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 17,475
#
# (4)  Total # of Summary of Episode Note files = 1
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:00:34.398649

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="28"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220628 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 1,932,125
#
# (4)  Total # of Summary of Episode Note files = 169
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:10:14.122245

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="29"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# (1)  Received CDW xml files:  Z:/CDW/20220629 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValley MedShare
#
# (3)  Total # of xml_files = 414,166
#
# (4)  Total # of Summary of Episode Note files = 36
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:02:08.011292

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="30"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220830 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 280,112
#
# (4)  Total # of Summary of Episode Note files = 20
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:01:37.796218

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="08"; day="31"; # Select month, day, and year


# ####################
# ####################

# %run -i "USENT_by_partnerName.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# C:\Users\vacoazizs1\Documents\USENT\USENT_by_partnerName.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False, usecols=['CCDA_File_Name', 'Document_LOINC_Code', 'Sending_Organization'])
# (1)  Received CDW xml files:  Z:/CDW/20220831 sample files
#
# (2)  Output Path C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\SacValleyMedShare_202206_xml
#
# (3)  Total # of xml_files = 373,161
#
# (4)  Total # of Summary of Episode Note files = 42
#
#
# (5)  Percent of Summary of Episode Note files in the folder/path = 0.01 %
#
#
# run time: hour:min:sec=  0:01:58.530717

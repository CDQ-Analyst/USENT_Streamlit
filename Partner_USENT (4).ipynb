# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="01"; # Select month, day, and year

# partner = 'Kansas HIN'
OID = '2.16.840.1.113883.3.8312.2.2.1.1'
output_path = r"C:\Users\vacoazizs1\Documents\Received_Zip\Received_CCDA\ICA\Kansas HIN"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# df.shape
# df.columns
# # df.Sending_Organization.value_counts()
# df1 =df.loc[df.Sending_Organization.str.contains("KansasHIN", case=False, na=False)]
# df1.head(2)
# Out:
#            EDIPI        SSN   Patient_Last_Name Patient_First_Name  \
# 1473  1463132140  666000001  CHDRZZZTESTPATIENT            CHDRONE
# 6049  1463132140  666000001  CHDRZZZTESTPATIENT            CHDRONE
#
#         Date_of_Reception_(UTC)                      Document_Format_Code  \
# 1473  2022-05-31 10:16:29+00:00  urn:hl7-org:sdwg:ccda-structuredBody:2.1
# 6049  2022-05-31 10:55:28+00:00  urn:hl7-org:sdwg:ccda-structuredBody:2.1
#
#                   User_Role Purpose_of_Use Purpose_of_Use_Code  PatientICN  \
# 1473  Public health officer      Treatment           TREATMENT  1017237188
# 6049  Public health officer      Treatment           TREATMENT  1017237188
#
#                                                                                         CERNER_INPUT_FILE  \
# 1473  \\vhacdwdwhftp05.vha.med.va.gov\VAAACSVCHIECP\Production\Processed-Receive\20220531100000_202205...
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="02"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="05"; day="03"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="05"; day="04"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="05"; day="05"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="06"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="07"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="08"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="09"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="15"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="16"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="20"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="21"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="22"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="23"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="27"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="28"; # Select month, day, and year

# partner = 'Midwest Health Connection'
# OID = '2.16.840.1.113883.3.2697'
# output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...

# %%
# USENT 
##################################################################
# Step 1:
Received_or_Disclosure = "Received"; # type Received or Disclosure

# # Step 2:
year="2022"; month="06"; day="29"; # Select month, day, and year

# partner = 'Midwest Health Connection'
OID = '2.16.840.1.113883.3.2697'
output_path = r"Z:\CDW\Team-Member\Aziz-Work-Folder\HIMSS Data\Intersystems\MHC"

# ####################
# ####################

# %run -i "Partner_USENT.py" 

#####################
#####################
# Out:
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# C:\Users\vacoazizs1\Documents\USENT\Partner_USENT.py:54: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_z=pd.read_csv(f,  error_bad_lines=False)
# ...
